# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(1, 11)
fig, a = plt.subplots(1, 3, figsize = (12, 4))
a[0].plot(x, x**3, 'g', lw=2)
a[0].grid(True)
a[0].set_title('default grid')

a[1].plot(x, np.exp(x), 'r')
a[1].grid(color = 'b', ls = '-.', lw = 0.25)
a[1].set_title('Custom Grid')

a[2].plot(x, x)
a[2].set_title('No grid')

fig.tight_layout()

# %%
x = np.arange(1, 11)
fig, a = plt.subplots(1, 3, figsize = (12, 4))
a[0].plot(x, x**3, 'g', lw=2)
a[0].grid(True)
a[0].set_title('default grid')

a[1].plot(x, np.exp(x), 'r')
a[1].grid(color = 'b', ls = '-.', lw = 0.25)
a[1].set_title('Custom Grid')

a[2].plot(x, x)
a[2].set_title('No grid')
# Out:
# Text(0.5, 1.0, 'No grid')

# %%
x = np.arange(1, 11)
fig, a = plt.subplots(1, 3, figsize = (12, 4))
a[0][0].plot(x, x**3, 'g', lw=2)
a[0][0].grid(True)
a[0][0].set_title('default grid')

a[0][1].plot(x, np.exp(x), 'r')
a[0][1].grid(color = 'b', ls = '-.', lw = 0.25)
a[0][1].set_title('Custom Grid')

a[0][2].plot(x, x)
a[0][2].set_title('No grid')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-4f1ee098b029> in <module>
#       1 x = np.arange(1, 11)
#       2 fig, a = plt.subplots(1, 3, figsize = (12, 4))
# ----> 3 a[0][0].plot(x, x**3, 'g', lw=2)
#       4 a[0][0].grid(True)
#       5 a[0][0].set_title('default grid')
#
# TypeError: 'AxesSubplot' object is not subscriptable
