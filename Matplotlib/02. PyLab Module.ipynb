# %%
import numpy as np
from pylab import *

# %%
x = np.linspace(-3, 3, 30)

# %%
y = x**2

# %%
plot(x, y)

# %% [markdown]
# #### To plot symbols rather than lines

# %%
plot(x, y, 'r--')

# %%
plot(x, y, 'g.')

# %%
plot(x, y, 'bd')

# %%
plot(x, y, 'cD')

# %%
plot(x, y, 'm1')

# %%
plot(x, y, 'y2')

# %%
plot(x, y, 'k3')

# %%
plot(x, y, 'r>')

# %%
plot(x, y, 'r+')

# %%
clf()          #To clear the plot

# %%
plot(x, np.sin(x))
plot(x, np.cos(x), 'r--')
plot(x, -np.sin(x), 'gd')
