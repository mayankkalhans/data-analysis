# %%
import matplotlib.pyplot as plt
import numpy as np
import math
# %matplotlib inline

# %%
x = np.arange(0, math.pi *2, 0.05)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)
plt.xlabel('angle')
plt.ylabel('sine')
plt.title('sine wave')
# Out:
# Text(0.5, 1.0, 'sine wave')
