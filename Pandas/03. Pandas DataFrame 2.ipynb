# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management']=df['Senior Management'].astype('bool')
df['Gender']=df['Gender'].astype('category')

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-03-01 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-03-01 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-03-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-03-01 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-03-01 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-03-01 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-03-01 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-03-01 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-03-01 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-03-01 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %% [markdown]
# ## Filter a Dataframe based on a Condition

# %%
mask = df['Team']=='Finance'
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-03-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-03-01 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2020-03-01 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2020-03-01 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2020-03-01 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2020-03-01 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2020-03-01 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2020-03-01 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2020-03-01 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2020-03-01 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# ...

# %%
mask = df['Salary']>=100000
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-03-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-03-01 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-03-01 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-03-01 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2020-03-01 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2020-03-01 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2020-03-01 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-03-01 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2020-03-01 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2020-03-01 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %% [markdown]
# ## Filter with more than one Condition

# %% [markdown]
# #### Using &(AND)

# %%
mask1 = df['Team'] == 'Finance'
mask2 = df['Salary'] >= 100000
df[mask1 & mask2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-03-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-03-01 13:00:00  138705    9.340
# 46       Bruce    Male 2009-11-28 2020-03-01 22:47:00  114796    6.796
# 56        Carl    Male 2006-05-03 2020-03-01 17:55:00  130276   16.084
# 69       Irene     NaN 2015-07-14 2020-03-01 16:31:00  100863    4.382
# 83       Shawn    Male 2005-09-23 2020-03-01 02:55:00  148115    6.539
# 96     Cynthia  Female 1994-03-21 2020-03-01 08:34:00  142321    1.737
# 103    Phyllis  Female 1996-10-11 2020-03-01 21:30:00  136984    8.932
# 117     Steven    Male 1995-03-01 2020-03-01 15:03:00  109095    9.494
# 142  Elizabeth  Female 2003-10-09 2020-03-01 17:53:00  146129    5.687
# 160      Kathy  Female 2000-03-18 2020-03-01 19:26:00  149563   16.991
# 205    Brandon    Male 2006-03-27 2020-03-01 17:54:00  115711    8.012
# ...

# %% [markdown]
# #### Using |(OR)

# %%
mask1 = df['Team'] == 'Finance'
mask2 = df['Salary'] >= 100000
df[mask1 | mask2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-03-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-03-01 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-03-01 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-03-01 01:35:00  115163   10.125
# 7          NaN  Female 2015-07-20 2020-03-01 10:43:00   45906   11.598
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2020-03-01 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-03-01 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2020-03-01 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-03-01 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2020-03-01 18:24:00  129949   10.169
#
#      Senior Management             Team
# 2                False          Finance
# ...

# %% [markdown]
# #### Using both & and |

# %%
mask1 = df['Team'] == 'Finance'
mask2 = df['Salary'] >= 100000
mask3 = df['Start Date'] > '1985-01-01'
df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-03-01 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-03-01 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-03-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-03-01 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-03-01 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-03-01 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2020-03-01 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2020-03-01 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-03-01 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-03-01 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# #### isin() Method
# Used to check multiple values in a column to avoid creation of multiple commands

# %%
mask = df['Team'].isin(['Legal', 'Finance', 'Marketing'])
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-03-01 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2020-03-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-03-01 13:00:00  138705    9.340
# 5       Dennis    Male 1987-04-18 2020-03-01 01:35:00  115163   10.125
# 7          NaN  Female 2015-07-20 2020-03-01 10:43:00   45906   11.598
# ..         ...     ...        ...                 ...     ...      ...
# 989     Justin     NaN 1991-02-10 2020-03-01 16:58:00   38344    3.794
# 991       Rose  Female 2002-08-25 2020-03-01 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-03-01 08:35:00  112769   11.625
# 994     George    Male 2013-06-21 2020-03-01 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-03-01 06:30:00   42392   19.675
#
#      Senior Management       Team
# 0                 True  Marketing
# 2                False    Finance
# ...

# %% [markdown]
# #### isnull() and notnull() Methods

# %%
mask = df['Gender'].isnull()
df[mask]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 20        Lois    NaN 1995-04-22 2020-03-01 19:18:00   64714    4.934
# 22      Joshua    NaN 2012-03-08 2020-03-01 01:58:00   90816   18.816
# 27       Scott    NaN 1991-07-11 2020-03-01 18:58:00  122367    5.218
# 31       Joyce    NaN 2005-02-20 2020-03-01 14:40:00   88657   12.752
# 41   Christine    NaN 2015-06-28 2020-03-01 01:08:00   66582   11.308
# ..         ...    ...        ...                 ...     ...      ...
# 961    Antonio    NaN 1989-06-18 2020-03-01 21:37:00  103050    3.050
# 972     Victor    NaN 2006-07-28 2020-03-01 14:49:00   76381   11.159
# 985    Stephen    NaN 1983-07-10 2020-03-01 20:10:00   85668    1.909
# 989     Justin    NaN 1991-02-10 2020-03-01 16:58:00   38344    3.794
# 995      Henry    NaN 2014-11-23 2020-03-01 06:09:00  132483   16.655
#
#      Senior Management                  Team
# 20                True                 Legal
# ...

# %%
mask = df['Gender'].notnull()
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-03-01 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-03-01 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-03-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-03-01 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-03-01 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-03-01 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-03-01 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-03-01 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-03-01 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-03-01 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# #### between() Method

# %%
df[df['Last Login Time'].between('08:30AM','01:00PM')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-03-01 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2020-03-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-03-01 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2020-03-01 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2020-03-01 09:01:00   63241   15.132
# ..         ...     ...        ...                 ...     ...      ...
# 977      Sarah  Female 1995-12-04 2020-03-01 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2020-03-01 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2020-03-01 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2020-03-01 08:35:00  112769   11.625
# 997    Russell    Male 2013-05-20 2020-03-01 12:39:00   96914    1.421
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
df[df['Last Login Time'].between('08:30:00','13:00:00')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-03-01 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2020-03-01 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-03-01 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2020-03-01 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2020-03-01 09:01:00   63241   15.132
# ..         ...     ...        ...                 ...     ...      ...
# 977      Sarah  Female 1995-12-04 2020-03-01 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2020-03-01 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2020-03-01 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2020-03-01 08:35:00  112769   11.625
# 997    Russell    Male 2013-05-20 2020-03-01 12:39:00   96914    1.421
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %% [markdown]
# #### duplicated() Method

# %%
df.sort_values('First Name', inplace=True) 
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-03-01 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-03-01 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-03-01 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-03-01 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2020-03-01 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2020-03-01 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-03-01 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-03-01 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-03-01 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2020-03-01 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
mask = df['First Name'].duplicated(keep='first')
mask
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2020-03-01 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-03-01 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-03-01 19:39:00   63126   18.424
# 141       Adam    Male 1990-12-24 2020-03-01 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2020-03-01 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2020-03-01 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-03-01 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-03-01 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-03-01 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2020-03-01 05:19:00  143638    9.662
#
#      Senior Management             Team
# 327               True        Marketing
# ...

# %%
mask = df.duplicated(subset=['First Name', 'Team'], keep='last')
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-03-01 10:20:00   61602   11.849
# 440      Aaron    Male 1990-07-22 2020-03-01 14:53:00   52119   11.343
# 302       Adam    Male 2007-07-05 2020-03-01 11:59:00   71276    5.027
# 372     Albert    Male 1997-02-01 2020-03-01 16:20:00   67827   19.717
# 477     Albert    Male 2008-08-14 2020-03-01 17:43:00  137840    9.705
# ..         ...     ...        ...                 ...     ...      ...
# 783        NaN     NaN 1991-04-15 2020-03-01 03:39:00  132505   13.592
# 785        NaN  Female 1982-07-24 2020-03-01 00:00:00   57811    8.941
# 821        NaN  Female 1980-12-27 2020-03-01 02:27:00   80399   12.254
# 826        NaN     NaN 1988-08-01 2020-03-01 01:35:00   87103    5.665
# 902        NaN    Male 2001-05-23 2020-03-01 19:52:00  103877    6.322
#
#      Senior Management                  Team
# 101               True             Marketing
# ...

# %%
mask = df['First Name'].duplicated(keep=False)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-03-01 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-03-01 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-03-01 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-03-01 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2020-03-01 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2020-03-01 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-03-01 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-03-01 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-03-01 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2020-03-01 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
mask = ~df['First Name'].duplicated(keep=False)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2020-03-01 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2020-03-01 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2020-03-01 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2020-03-01 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2020-03-01 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2020-03-01 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2020-03-01 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2020-03-01 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2020-03-01 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %% [markdown]
# #### drop_duplicates() Method

# %%
df.drop_duplicates(subset=['First Name'])
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-03-01 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2020-03-01 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2020-03-01 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2020-03-01 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2020-03-01 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2020-03-01 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2020-03-01 08:00:00  102652   14.085
# 941    William    Male 1997-06-26 2020-03-01 08:33:00  104840   15.653
# 450     Willie    Male 2009-08-22 2020-03-01 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2020-03-01 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
df.drop_duplicates(subset=['First Name'],  keep='last')
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 937      Aaron     NaN 1986-01-22 2020-03-01 19:39:00   63126   18.424
# 538       Adam    Male 2010-10-08 2020-03-01 21:53:00   45181    3.491
# 610       Alan    Male 2012-02-17 2020-03-01 00:26:00   41453   10.084
# 959     Albert    Male 1992-09-19 2020-03-01 02:35:00   45094    5.850
# 693      Alice  Female 1995-10-16 2020-03-01 21:19:00   92799    2.782
# ..         ...     ...        ...                 ...     ...      ...
# 512      Wanda  Female 1993-04-06 2020-03-01 03:11:00   78883   19.695
# 637      Wayne    Male 2009-09-02 2020-03-01 01:37:00  126956   18.396
# 820    William    Male 1993-11-18 2020-03-01 12:27:00   54058    5.182
# 652     Willie    Male 2009-12-05 2020-03-01 05:39:00  141932    1.017
# 951        NaN  Female 2010-09-14 2020-03-01 05:19:00  143638    9.662
#
#      Senior Management                  Team
# 937              False       Client Services
# ...

# %%
df.drop_duplicates(subset=['First Name'],  keep=False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2020-03-01 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2020-03-01 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2020-03-01 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2020-03-01 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2020-03-01 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2020-03-01 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2020-03-01 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2020-03-01 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2020-03-01 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %% [markdown]
# #### unique() and nunique() Method

# %%
df['Gender'].unique()
# Out:
# [Male, NaN, Female]
# Categories (2, object): [Male, Female]

# %%
len(df['Gender'].unique())
# Out:
# 3

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].nunique(dropna=False)
# Out:
# 3
