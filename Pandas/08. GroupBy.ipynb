# %%
import pandas as pd
import numpy as np

# %%
fortune = pd.read_csv('fortune1000.csv', index_col = 'Rank')
sectors = fortune.groupby('Sector')
fortune
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
type(fortune)
# Out:
# pandas.core.frame.DataFrame

# %%
type(sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# ## Some Methods on GroupBy object

# %%
len(fortune)
# Out:
# 1000

# %%
len(sectors)
# Out:
# 21

# %%
fortune.size
# Out:
# 7000

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
sectors.first()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
sectors.last()
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# ...

# %% [markdown]
# ## groups Attribute

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': Int64Index([ 24,  45,  60,  88, 118, 120, 209, 245, 282, 378, 389, 490, 560,
#              605, 785, 788, 836, 903, 958, 987],
#             dtype='int64', name='Rank'),
#  'Apparel': Int64Index([91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877,
#              882, 917],
#             dtype='int64', name='Rank'),
#  'Business Services': Int64Index([144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404,
#              440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694,
#              714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796,
#              801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993],
#             dtype='int64', name='Rank'),
#  'Chemicals': Int64Index([ 56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549,
#              555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829,
#              865, 898, 934, 949],
#             dtype='int64', name='Rank'),
# ...

# %% [markdown]
# ## Retrieve a Group with .get_group() Method

# %%
sectors.get_group('Energy')
# Out:
#                         Company                      Industry  \
# Rank
# 2                   Exxon Mobil            Petroleum Refining
# 14                      Chevron            Petroleum Refining
# 30                  Phillips 66            Petroleum Refining
# 32                Valero Energy            Petroleum Refining
# 42           Marathon Petroleum            Petroleum Refining
# ...                         ...                           ...
# 981                  WPX Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy            Petroleum Refining
# 995                   EP Energy  Mining, Crude-Oil Production
# 997   Portland General Electric   Utilities: Gas and Electric
# 997   Portland General Electric   Utilities: Gas and Electric
#
#              Location  Revenue  Profits  Employees
# Rank
# 2          Irving, TX   246204    16150      75600
# 14      San Ramon, CA   131118     4587      61500
# 30        Houston, TX    87169     4227      14000
# ...

# %%
sectors.get_group("Apparel")
# Out:
#                    Company Industry             Location  Revenue  Profits  \
# Rank
# 91                    Nike  Apparel        Beaverton, OR    30601     3273
# 231                     VF  Apparel       Greensboro, NC    12377     1232
# 340                    PVH  Apparel         New York, NY     8020      572
# 354           Ralph Lauren  Apparel         New York, NY     7620      702
# 448            Hanesbrands  Apparel    Winston-Salem, NC     5732      429
# 547           Levi Strauss  Apparel    San Francisco, CA     4495      209
# 575                  Coach  Apparel         New York, NY     4192      402
# 597           Under Armour  Apparel        Baltimore, MD     3963      233
# 683           Fossil Group  Apparel       Richardson, TX     3229      221
# 695        Skechers U.S.A.  Apparel  Manhattan Beach, CA     3159      232
# 726               Carter’s  Apparel          Atlanta, GA     3014      238
# ...

# %% [markdown]
# ## Some more Methods

# %% [markdown]
# #### max() and min()

# %%
sectors.max()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                         Woodward
# Apparel                         Wolverine World Wide
# Business Services                      Western Union
# Chemicals                          Westlake Chemical
# Energy                                   Xcel Energy
# Engineering & Construction              Tutor Perini
# Financials                            Zions Bancorp.
# Food and Drug Stores              Whole Foods Market
# Food, Beverages & Tobacco            WhiteWave Foods
# Health Care                          inVentiv Health
# Hotels, Resturants & Leisure              Yum Brands
# Household Products                     Vista Outdoor
# Industrials                       Zebra Technologies
# Materials                     Worthington Industries
# Media                                    iHeartMedia
# Motor Vehicles & Parts               Wabash National
# ...

# %%
sectors.min()
# Out:
#                                                     Company  \
# Sector
# Aerospace & Defense                           B/E Aerospace
# Apparel                                            Carter’s
# Business Services                            ABM Industries
# Chemicals                                       A. Schulman
# Energy                                                  AES
# Engineering & Construction                            AECOM
# Financials                                              AIG
# Food and Drug Stores                             CVS Health
# Food, Beverages & Tobacco        Alliance One International
# Health Care                                          AbbVie
# Hotels, Resturants & Leisure                Bloomin’ Brands
# Household Products                            Avon Products
# Industrials                                              3M
# Materials                            A-Mark Precious Metals
# ...

# %%
sectors['Revenue'].max()
# Out:
# Sector
# Aerospace & Defense              96114
# Apparel                          30601
# Business Services                19330
# Chemicals                        48778
# Energy                          246204
# Engineering & Construction       18114
# Financials                      210821
# Food and Drug Stores            153290
# Food, Beverages & Tobacco        67702
# Health Care                     181241
# Hotels, Resturants & Leisure     25413
# Household Products               78756
# Industrials                     140389
# Materials                        22534
# Media                            52465
# Motor Vehicles & Parts          152356
# Retailing                       482130
# Technology                      233715
# Telecommunications              146801
# Transportation                   58363
# Wholesalers                      48681
# Name: Revenue, dtype: int64

# %%
sectors[['Revenue', 'Profits']].min()
# Out:
#                               Revenue  Profits
# Sector
# Aerospace & Defense              1923     -240
# Apparel                          2204       82
# Business Services                1910    -1481
# Chemicals                        2084     -816
# Energy                           1898   -23119
# Engineering & Construction       1909     -155
# Financials                       1902    -1194
# Food and Drug Stores             2151      -62
# Food, Beverages & Tobacco        2066     -253
# Health Care                      1987     -458
# Hotels, Resturants & Leisure     1896    -1394
# Household Products               1914    -1149
# Industrials                      1895    -6126
# Materials                        1924    -1642
# Media                            1921     -881
# Motor Vehicles & Parts           1986     -889
# Retailing                        1999    -1243
# Technology                       1920    -4359
# Telecommunications               2726     -271
# ...

# %% [markdown]
# #### sum() and mean()

# %%
sectors.sum()
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
sectors.mean()
# Out:
#                                    Revenue      Profits     Employees
# Sector
# Aerospace & Defense           17897.000000  1437.100000  48402.850000
# Apparel                        6397.866667   549.066667  23093.133333
# Business Services              5337.156863   553.470588  26687.254902
# Chemicals                      8129.900000   754.266667  15455.033333
# Energy                        12441.057377  -602.024590   9745.303279
# Engineering & Construction     5922.423077   204.000000  15642.615385
# Financials                    15950.784173  1872.007194  24172.287770
# Food and Drug Stores          32251.266667  1117.266667  93026.533333
# Food, Beverages & Tobacco     12929.465116  1195.744186  28177.488372
# Health Care                   21529.426667  1414.853333  35710.520000
# Hotels, Resturants & Leisure   6781.840000   827.880000  99369.800000
# Household Products             8383.464286   515.285714  23072.785714
# ...

# %%
sectors['Revenue'].mean()
# Out:
# Sector
# Aerospace & Defense             17897.000000
# Apparel                          6397.866667
# Business Services                5337.156863
# Chemicals                        8129.900000
# Energy                          12441.057377
# Engineering & Construction       5922.423077
# Financials                      15950.784173
# Food and Drug Stores            32251.266667
# Food, Beverages & Tobacco       12929.465116
# Health Care                     21529.426667
# Hotels, Resturants & Leisure     6781.840000
# Household Products               8383.464286
# Industrials                     10816.978261
# Materials                        6026.627907
# Media                            8830.560000
# Motor Vehicles & Parts          20105.833333
# Retailing                       18313.450000
# Technology                      13505.882353
# Telecommunications              30788.933333
# Transportation                  11347.444444
# Wholesalers                     11120.000000
# ...

# %%
sectors['Revenue'].sum()
# Out:
# Sector
# Aerospace & Defense              357940
# Apparel                           95968
# Business Services                272195
# Chemicals                        243897
# Energy                          1517809
# Engineering & Construction       153983
# Financials                      2217159
# Food and Drug Stores             483769
# Food, Beverages & Tobacco        555967
# Health Care                     1614707
# Hotels, Resturants & Leisure     169546
# Household Products               234737
# Industrials                      497581
# Materials                        259145
# Media                            220764
# Motor Vehicles & Parts           482540
# Retailing                       1465076
# Technology                      1377600
# Telecommunications               461834
# Transportation                   408508
# Wholesalers                      444800
# Name: Revenue, dtype: int64

# %% [markdown]
# ## Grouping by Multiple Columns

# %%
company = fortune.groupby(['Sector', 'Industry'])

# %%
company.size()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            20
# Apparel              Apparel                                          15
# Business Services    Advertising, marketing                            2
#                      Diversified Outsourcing Services                 14
#                      Education                                         3
#                                                                       ..
# Transportation       Trucking, Truck Leasing                           9
# Wholesalers          Miscellaneous                                     1
#                      Wholesalers: Diversified                         25
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
# Length: 79, dtype: int64

# %%
company.sum()
# Out:
#                                                                    Revenue  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                           357940
# Apparel             Apparel                                          95968
# Business Services   Advertising, marketing                           22748
#                     Diversified Outsourcing Services                 64829
#                     Education                                         7485
# ...                                                                    ...
# Transportation      Trucking, Truck Leasing                          35950
# Wholesalers         Miscellaneous                                     8982
#                     Wholesalers: Diversified                        176138
#                     Wholesalers: Electronics and Office Equipment   147906
#                     Wholesalers: Food and Grocery                   111774
#
# ...

# %%
company['Revenue'].mean()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            17897.000000
# Apparel              Apparel                                           6397.866667
# Business Services    Advertising, marketing                           11374.000000
#                      Diversified Outsourcing Services                  4630.642857
#                      Education                                         2495.000000
#                                                                           ...
# Transportation       Trucking, Truck Leasing                           3994.444444
# Wholesalers          Miscellaneous                                     8982.000000
#                      Wholesalers: Diversified                          7045.520000
#                      Wholesalers: Electronics and Office Equipment    18488.250000
#                      Wholesalers: Food and Grocery                    18629.000000
# ...

# %% [markdown]
# ## agg() Method

# %%
sectors.agg('sum')
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
sectors.agg({'Revenue':'sum', 'Profits':'sum', 'Employees':'mean'})
# Out:
#                               Revenue  Profits     Employees
# Sector
# Aerospace & Defense            357940    28742  48402.850000
# Apparel                         95968     8236  23093.133333
# Business Services              272195    28227  26687.254902
# Chemicals                      243897    22628  15455.033333
# Energy                        1517809   -73447   9745.303279
# Engineering & Construction     153983     5304  15642.615385
# Financials                    2217159   260209  24172.287770
# Food and Drug Stores           483769    16759  93026.533333
# Food, Beverages & Tobacco      555967    51417  28177.488372
# Health Care                   1614707   106114  35710.520000
# Hotels, Resturants & Leisure   169546    20697  99369.800000
# Household Products             234737    14428  23072.785714
# Industrials                    497581    20764  33591.934783
# Materials                      259145     4428  14840.069767
# ...

# %%
sectors.agg(['sum', 'median', 'std'])
# Out:
#                               Revenue                       Profits         \
#                                   sum  median           std     sum median
# Sector
# Aerospace & Defense            357940  6832.0  24468.237017   28742  566.5
# Apparel                         95968  3963.0   7254.770616    8236  233.0
# Business Services              272195  3160.0   4102.377498   28227  296.0
# Chemicals                      243897  4224.0   9575.323185   22628  367.5
# Energy                        1517809  5271.0  27362.358215  -73447  188.5
# Engineering & Construction     153983  4564.5   4579.682742    5304  150.5
# Financials                    2217159  5674.0  27105.928018  260209  583.0
# Food and Drug Stores           483769  3971.0  48595.512604   16759  192.0
# Food, Beverages & Tobacco      555967  6028.0  15732.585231   51417  498.0
# Health Care                   1614707  7098.0  35680.266614  106114  346.0
# ...

# %%
sectors.agg({'Revenue':['sum', 'mean'], 'Profits':'sum', 'Employees':'mean'})
# Out:
#                               Revenue               Profits     Employees
#                                   sum          mean     sum          mean
# Sector
# Aerospace & Defense            357940  17897.000000   28742  48402.850000
# Apparel                         95968   6397.866667    8236  23093.133333
# Business Services              272195   5337.156863   28227  26687.254902
# Chemicals                      243897   8129.900000   22628  15455.033333
# Energy                        1517809  12441.057377  -73447   9745.303279
# Engineering & Construction     153983   5922.423077    5304  15642.615385
# Financials                    2217159  15950.784173  260209  24172.287770
# Food and Drug Stores           483769  32251.266667   16759  93026.533333
# Food, Beverages & Tobacco      555967  12929.465116   51417  28177.488372
# Health Care                   1614707  21529.426667  106114  35710.520000
# Hotels, Resturants & Leisure   169546   6781.840000   20697  99369.800000
# ...

# %% [markdown]
# ## Iterating through Groups

# %%
for sector, data in sectors:
    print(sector)
    print(data)
# Out:
# Aerospace & Defense
#                             Company               Sector  \
# Rank
# 24                           Boeing  Aerospace & Defense
# 45              United Technologies  Aerospace & Defense
# 60                  Lockheed Martin  Aerospace & Defense
# 88                 General Dynamics  Aerospace & Defense
# 118                Northrop Grumman  Aerospace & Defense
# 120                        Raytheon  Aerospace & Defense
# 209                         Textron  Aerospace & Defense
# 245              L-3 Communications  Aerospace & Defense
# 282             Precision Castparts  Aerospace & Defense
# 378   Huntington Ingalls Industries  Aerospace & Defense
# 389     Spirit AeroSystems Holdings  Aerospace & Defense
# 490                Rockwell Collins  Aerospace & Defense
# 560                     Orbital ATK  Aerospace & Defense
# 605                   Triumph Group  Aerospace & Defense
# 785                   B/E Aerospace  Aerospace & Defense
# ...

# %%
df = pd.DataFrame(columns = fortune.columns)
for sector, data in sectors:
    highest_revenue = data.nlargest(1, 'Revenue')
    df = df.append(highest_revenue)

# %%
df
# Out:
#                     Company                        Sector  \
# 24                   Boeing           Aerospace & Defense
# 91                     Nike                       Apparel
# 144           ManpowerGroup             Business Services
# 56             Dow Chemical                     Chemicals
# 2               Exxon Mobil                        Energy
# 155                   Fluor    Engineering & Construction
# 4        Berkshire Hathaway                    Financials
# 7                CVS Health          Food and Drug Stores
# 41   Archer Daniels Midland     Food, Beverages & Tobacco
# 5                  McKesson                   Health Care
# 109              McDonald’s  Hotels, Resturants & Leisure
# 34         Procter & Gamble            Household Products
# 11         General Electric                   Industrials
# 126                   Alcoa                     Materials
# 53                   Disney                         Media
# ...

# %%
cities = fortune.groupby('Location')

# %%
df = pd.DataFrame(columns = fortune.columns)
for city, data in cities:
    highest_revenue = data.nlargest(1, 'Revenue')
    df = df.append(highest_revenue)

# %%
df
# Out:
#                       Company                        Sector  \
# 138       Abbott Laboratories                   Health Care
# 169    Goodyear Tire & Rubber        Motor Vehicles & Parts
# 288  Air Products & Chemicals                     Chemicals
# 830     Benchmark Electronics                    Technology
# 374    Casey’s General Stores                     Retailing
# ..                        ...                           ...
# 7                  CVS Health          Food and Drug Stores
# 506   Hanover Insurance Group                    Financials
# 764      Penn National Gaming  Hotels, Resturants & Leisure
# 773            Bon-Ton Stores                     Retailing
# 932             Herman Miller            Household Products
#
#                                            Industry         Location Revenue  \
# 138                  Medical Products and Equipment  Abbott Park, IL   20661
# 169                        Motor Vehicles and Parts        Akron, OH   16443
# ...
